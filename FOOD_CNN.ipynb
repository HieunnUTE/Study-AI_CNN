# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import Flatten, Dense, Dropout, Activation
from google.colab import drive
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import load_img,img_to_array

# %%
#conect drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#create data
drive.mount('/content/drive',force_remount=True)
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
train=train_datagen.flow_from_directory('/content/drive/MyDrive/CNN_10foodVN/train',
                                          target_size=(128,128),
                                          batch_size=32,
                                          class_mode ='categorical')
test=train_datagen.flow_from_directory('/content/drive/MyDrive/CNN_10foodVN/test',
                                          target_size=(128,128),
                                          batch_size=32,
                                          class_mode ='categorical')
# Out:
# Mounted at /content/drive
# Found 100 images belonging to 10 classes.
# Found 30 images belonging to 10 classes.

# %%
#create model
model=Sequential()

model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(128,128,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(64,activation='relu',kernel_initializer = 'he_uniform'))
model.add(Dense(10,activation='Softmax'))

model.compile(optimizer = 'adam', loss ='categorical_crossentropy',metrics = ['accuracy'])
callbacks=[EarlyStopping(monitor='val_loss',patience=100)]
history=model.fit(train,
                  steps_per_epoch=len(train),
                  batch_size = 100,
                  epochs=50,
                  validation_data=test,
                  validation_steps=len(test),
                  callbacks=callbacks,
                  verbose = 1)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 68s 15s/step - loss: 2.8626 - accuracy: 0.0800 - val_loss: 2.3022 - val_accuracy: 0.0667
# Epoch 2/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.2996 - accuracy: 0.1200 - val_loss: 2.2960 - val_accuracy: 0.0667
# Epoch 3/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.2989 - accuracy: 0.1300 - val_loss: 2.2979 - val_accuracy: 0.0667
# Epoch 4/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.2883 - accuracy: 0.1200 - val_loss: 2.3064 - val_accuracy: 0.0667
# Epoch 5/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.2588 - accuracy: 0.1600 - val_loss: 2.3035 - val_accuracy: 0.1333
# Epoch 6/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.2310 - accuracy: 0.1400 - val_loss: 2.3873 - val_accuracy: 0.1000
# Epoch 7/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.2349 - accuracy: 0.1900 - val_loss: 2.3358 - val_accuracy: 0.1333
# Epoch 8/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.2145 - accuracy: 0.2600 - val_loss: 2.3674 - val_accuracy: 0.0667
# Epoch 9/50
# 4/4 [==============================] - 10s 3s/step - loss: 2.1931 - accuracy: 0.1800 - val_loss: 2.3540 - val_accuracy: 0.1333
# Epoch 10/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.0967 - accuracy: 0.2500 - val_loss: 2.3991 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.1563 - accuracy: 0.2700 - val_loss: 2.5437 - val_accuracy: 0.0667
# Epoch 12/50
# 4/4 [==============================] - 10s 3s/step - loss: 1.9667 - accuracy: 0.2300 - val_loss: 2.5451 - val_accuracy: 0.1333
# Epoch 13/50
# 4/4 [==============================] - 10s 2s/step - loss: 1.8779 - accuracy: 0.3000 - val_loss: 2.8041 - val_accuracy: 0.1333
# Epoch 14/50
# 4/4 [==============================] - 10s 2s/step - loss: 1.6569 - accuracy: 0.4700 - val_loss: 3.4299 - val_accuracy: 0.1000
# Epoch 15/50
# 4/4 [==============================] - 10s 2s/step - loss: 2.0519 - accuracy: 0.3200 - val_loss: 2.7734 - val_accuracy: 0.1333
# Epoch 16/50
# 4/4 [==============================] - 10s 3s/step - loss: 1.9110 - accuracy: 0.3100 - val_loss: 2.5095 - val_accuracy: 0.0667
# Epoch 17/50
# 4/4 [==============================] - 10s 3s/step - loss: 1.8170 - accuracy: 0.4000 - val_loss: 2.5954 - val_accuracy: 0.0667
# Epoch 18/50
# 4/4 [==============================] - 10s 2s/step - loss: 1.7902 - accuracy: 0.3900 - val_loss: 2.9260 - val_accuracy: 0.1000
# Epoch 19/50
# 4/4 [==============================] - 10s 2s/step - loss: 1.7383 - accuracy: 0.4800 - val_loss: 2.7020 - val_accuracy: 0.2000
# Epoch 20/50
# 4/4 [==============================] - 10s 2s/step - loss: 1.5923 - accuracy: 0.5400 - val_loss: 2.5443 - val_accuracy: 0.2333
# Epoch 21/50
# 4/4 [==============================] - 10s 3s/step - loss: 1.3772 - accuracy: 0.5100 - val_loss: 2.7965 - val_accuracy: 0.2333
# Epoch 22/50
# 4/4 [==============================] - 10s 2s/step - loss: 1.3470 - accuracy: 0.5800 - val_loss: 2.7512 - val_accuracy: 0.3333
# Epoch 23/50
# 4/4 [==============================] - 10s 2s/step - loss: 1.0420 - accuracy: 0.6400 - val_loss: 3.3346 - val_accuracy: 0.3000
# Epoch 24/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.9167 - accuracy: 0.6900 - val_loss: 2.6826 - val_accuracy: 0.3000
# Epoch 25/50
# 4/4 [==============================] - 10s 2s/step - loss: 1.0620 - accuracy: 0.6300 - val_loss: 3.2829 - val_accuracy: 0.2333
# Epoch 26/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.8754 - accuracy: 0.7300 - val_loss: 2.8065 - val_accuracy: 0.3333
# Epoch 27/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.8505 - accuracy: 0.7000 - val_loss: 2.9734 - val_accuracy: 0.3667
# Epoch 28/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.7063 - accuracy: 0.7500 - val_loss: 3.1193 - val_accuracy: 0.3333
# Epoch 29/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.6052 - accuracy: 0.8300 - val_loss: 3.3222 - val_accuracy: 0.3667
# Epoch 30/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.6028 - accuracy: 0.8300 - val_loss: 3.1548 - val_accuracy: 0.2667
# Epoch 31/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.4949 - accuracy: 0.8700 - val_loss: 3.9595 - val_accuracy: 0.4000
# Epoch 32/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.5023 - accuracy: 0.8100 - val_loss: 3.7020 - val_accuracy: 0.3333
# Epoch 33/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.4521 - accuracy: 0.8400 - val_loss: 3.6943 - val_accuracy: 0.2000
# Epoch 34/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.3523 - accuracy: 0.8800 - val_loss: 3.2963 - val_accuracy: 0.4333
# Epoch 35/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.3024 - accuracy: 0.9100 - val_loss: 3.7063 - val_accuracy: 0.3667
# Epoch 36/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.4385 - accuracy: 0.8700 - val_loss: 2.9045 - val_accuracy: 0.4000
# Epoch 37/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.2960 - accuracy: 0.9100 - val_loss: 4.0451 - val_accuracy: 0.3333
# Epoch 38/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.2452 - accuracy: 0.9300 - val_loss: 4.5134 - val_accuracy: 0.3000
# Epoch 39/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.2836 - accuracy: 0.9300 - val_loss: 4.4220 - val_accuracy: 0.3000
# Epoch 40/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1342 - accuracy: 0.9700 - val_loss: 4.2530 - val_accuracy: 0.3333
# Epoch 41/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.2716 - accuracy: 0.9000 - val_loss: 4.8043 - val_accuracy: 0.3667
# Epoch 42/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.2162 - accuracy: 0.9500 - val_loss: 4.9298 - val_accuracy: 0.3667
# Epoch 43/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.7837 - accuracy: 0.7400 - val_loss: 4.0716 - val_accuracy: 0.4000
# Epoch 44/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.7071 - accuracy: 0.7900 - val_loss: 4.2257 - val_accuracy: 0.2667
# Epoch 45/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.4564 - accuracy: 0.8300 - val_loss: 4.4438 - val_accuracy: 0.2333
# Epoch 46/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.3408 - accuracy: 0.8800 - val_loss: 4.1321 - val_accuracy: 0.3000
# Epoch 47/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.2197 - accuracy: 0.9400 - val_loss: 3.8506 - val_accuracy: 0.4000
# Epoch 48/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.1559 - accuracy: 0.9600 - val_loss: 3.8883 - val_accuracy: 0.3333
# Epoch 49/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.3035 - accuracy: 0.9300 - val_loss: 3.9188 - val_accuracy: 0.3000
# Epoch 50/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.2947 - accuracy: 0.8800 - val_loss: 3.6663 - val_accuracy: 0.2667

# %%
model.save('BTVN-CNN-FOOD.h5')

# %%
label = ['BanhMi','BanhXeo','BunBo','BunRieu','BunThitNuong','ComSuon','Goi','GoiCuon','Nem','Pho']

# %%
import matplotlib.pyplot as plt
score = model.evaluate(test,verbose=0)
print('Test loss= ',score[0])
print('Test accuracy= ',score[1])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'],loc='upper left')
# Out:
# Test loss=  5.6939239501953125
# Test accuracy=  0.4000000059604645

# %%
from keras.models import load_model
model = load_model('CNN_10foodVN.h5')

# %%
import numpy as np
from tensorflow.keras.utils import load_img,img_to_array
img = load_img('/content/foody-upload-api-foody-mobile-1-191225095502.jpg', target_size = (128,128))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,128,128,3) 
img = img.astype('float32')
img = img/255
print(label[np.argmax(model.predict(img))])
# Out:
# BanhMi
